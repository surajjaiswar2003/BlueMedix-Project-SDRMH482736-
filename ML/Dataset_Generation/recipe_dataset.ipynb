# %%
import pandas as pd

def create_comprehensive_recipe_dataset():
    # Define the recipe data with all 45 recipes
    recipes = [
        # Breakfast recipes
        {"recipe_id": 1, "name": "Greek Yogurt with Berries and Chia Seeds", "meal_type": "breakfast", "protein": 18, "carbs": 25, "fat": 6, "calories": 240, "sodium": 70, "fiber": 8, "ingredients": "Greek yogurt, mixed berries, chia seeds, honey", "instructions": "Mix 1 cup of Greek yogurt with 1/2 cup berries, 1 tbsp chia seeds, and a drizzle of honey", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mediterranean", "cooking_difficulty": "Easy", "prep_time": 5},

        {"recipe_id": 2, "name": "Avocado Toast with Poached Egg", "meal_type": "breakfast", "protein": 14, "carbs": 28, "fat": 15, "calories": 320, "sodium": 380, "fiber": 7, "ingredients": "Whole grain bread, avocado, egg, tomato, salt, pepper", "instructions": "Toast bread, spread avocado, add sliced tomato, top with poached egg", "vegetarian": True, "vegan": False, "gluten_free": False, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 10},

        {"recipe_id": 3, "name": "Spinach and Mushroom Omelette", "meal_type": "breakfast", "protein": 20, "carbs": 5, "fat": 16, "calories": 280, "sodium": 320, "fiber": 2, "ingredients": "Eggs, spinach, mushrooms, feta cheese, olive oil", "instructions": "Sauté vegetables, add beaten eggs, fold with feta cheese", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mediterranean", "cooking_difficulty": "Medium", "prep_time": 15},

        {"recipe_id": 4, "name": "Overnight Oats with Almond Butter", "meal_type": "breakfast", "protein": 12, "carbs": 45, "fat": 10, "calories": 310, "sodium": 50, "fiber": 8, "ingredients": "Rolled oats, almond milk, almond butter, banana, cinnamon", "instructions": "Combine ingredients, refrigerate overnight, add banana before serving", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Easy", "prep_time": 8},

        {"recipe_id": 5, "name": "Breakfast Smoothie Bowl", "meal_type": "breakfast", "protein": 15, "carbs": 35, "fat": 8, "calories": 270, "sodium": 60, "fiber": 6, "ingredients": "Banana, spinach, protein powder, almond milk, berries, nuts", "instructions": "Blend ingredients except toppings, pour in bowl, add toppings", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Easy", "prep_time": 10},

        {"recipe_id": 6, "name": "Whole Grain Pancakes with Berries", "meal_type": "breakfast", "protein": 10, "carbs": 40, "fat": 8, "calories": 280, "sodium": 300, "fiber": 5, "ingredients": "Whole grain flour, egg, milk, baking powder, berries, maple syrup", "instructions": "Mix batter, cook pancakes, top with fresh berries and small amount of syrup", "vegetarian": True, "vegan": False, "gluten_free": False, "diabetes_friendly": False, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 20},

        {"recipe_id": 7, "name": "Tofu Scramble with Vegetables", "meal_type": "breakfast", "protein": 16, "carbs": 15, "fat": 12, "calories": 240, "sodium": 250, "fiber": 5, "ingredients": "Firm tofu, bell peppers, spinach, turmeric, nutritional yeast", "instructions": "Crumble and sauté tofu with vegetables and spices", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Asian", "cooking_difficulty": "Medium", "prep_time": 15},

        {"recipe_id": 8, "name": "Low-Carb Breakfast Bowl", "meal_type": "breakfast", "protein": 22, "carbs": 8, "fat": 18, "calories": 290, "sodium": 450, "fiber": 3, "ingredients": "Ground turkey, bell peppers, eggs, avocado, salsa", "instructions": "Cook turkey with peppers, add eggs, top with avocado and salsa", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 20},

        {"recipe_id": 9, "name": "Quinoa Breakfast Bowl", "meal_type": "breakfast", "protein": 12, "carbs": 38, "fat": 9, "calories": 280, "sodium": 40, "fiber": 6, "ingredients": "Quinoa, milk, cinnamon, apple, walnuts, maple syrup", "instructions": "Cook quinoa with milk and cinnamon, top with apples and walnuts", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 25},

        {"recipe_id": 10, "name": "Cottage Cheese with Fruit", "meal_type": "breakfast", "protein": 25, "carbs": 20, "fat": 5, "calories": 230, "sodium": 400, "fiber": 3, "ingredients": "Cottage cheese, pineapple, berries, walnuts", "instructions": "Mix cottage cheese with fruits, top with nuts", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "American", "cooking_difficulty": "Easy", "prep_time": 5},

        {"recipe_id": 11, "name": "Buckwheat Porridge", "meal_type": "breakfast", "protein": 8, "carbs": 35, "fat": 7, "calories": 230, "sodium": 15, "fiber": 6, "ingredients": "Buckwheat groats, milk, banana, cinnamon, flaxseeds", "instructions": "Cook buckwheat, add milk and flavorings", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "European", "cooking_difficulty": "Medium", "prep_time": 20},

        {"recipe_id": 12, "name": "Smoked Salmon on Rye with Cream Cheese", "meal_type": "breakfast", "protein": 18, "carbs": 20, "fat": 14, "calories": 280, "sodium": 570, "fiber": 4, "ingredients": "Rye bread, smoked salmon, light cream cheese, capers, dill", "instructions": "Spread bread with cream cheese, top with salmon, capers, and dill", "vegetarian": False, "vegan": False, "gluten_free": False, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "European", "cooking_difficulty": "Easy", "prep_time": 7},

        {"recipe_id": 13, "name": "High-Fiber Breakfast Muffins", "meal_type": "breakfast", "protein": 7, "carbs": 25, "fat": 10, "calories": 220, "sodium": 200, "fiber": 9, "ingredients": "Oat flour, bran, banana, egg, yogurt, walnuts, cinnamon", "instructions": "Mix ingredients, bake in muffin tin", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 30},

        {"recipe_id": 14, "name": "Savory Breakfast Quinoa", "meal_type": "breakfast", "protein": 14, "carbs": 30, "fat": 12, "calories": 280, "sodium": 280, "fiber": 5, "ingredients": "Quinoa, vegetable broth, egg, avocado, cherry tomatoes", "instructions": "Cook quinoa in broth, top with fried egg, avocado, and tomatoes", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mediterranean", "cooking_difficulty": "Medium", "prep_time": 20},

        {"recipe_id": 15, "name": "Protein-Packed Chia Pudding", "meal_type": "breakfast", "protein": 15, "carbs": 20, "fat": 14, "calories": 270, "sodium": 45, "fiber": 10, "ingredients": "Chia seeds, protein powder, almond milk, berries, honey", "instructions": "Mix ingredients except berries, refrigerate overnight, top with berries", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Easy", "prep_time": 8},

        # Lunch recipes
        {"recipe_id": 16, "name": "Mediterranean Bowl with Chickpeas", "meal_type": "lunch", "protein": 18, "carbs": 45, "fat": 12, "calories": 360, "sodium": 380, "fiber": 12, "ingredients": "Chickpeas, quinoa, cucumber, tomatoes, feta, olives, olive oil", "instructions": "Combine all ingredients, drizzle with olive oil and lemon juice", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Mediterranean", "cooking_difficulty": "Easy", "prep_time": 15},

        {"recipe_id": 17, "name": "Grilled Chicken Salad with Avocado", "meal_type": "lunch", "protein": 30, "carbs": 12, "fat": 15, "calories": 320, "sodium": 350, "fiber": 7, "ingredients": "Chicken breast, mixed greens, avocado, cherry tomatoes, olive oil", "instructions": "Grill chicken, slice and add to salad with other ingredients", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 20},

        {"recipe_id": 18, "name": "Lentil Soup with Vegetables", "meal_type": "lunch", "protein": 16, "carbs": 35, "fat": 6, "calories": 260, "sodium": 310, "fiber": 12, "ingredients": "Lentils, carrots, onions, celery, tomatoes, vegetable broth, spices", "instructions": "Sauté vegetables, add lentils and broth, simmer until tender", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mediterranean", "cooking_difficulty": "Easy", "prep_time": 40},

        {"recipe_id": 19, "name": "Tuna Salad Stuffed Avocado", "meal_type": "lunch", "protein": 25, "carbs": 10, "fat": 20, "calories": 320, "sodium": 400, "fiber": 7, "ingredients": "Canned tuna, greek yogurt, celery, red onion, lemon juice, avocado", "instructions": "Mix tuna with yogurt and vegetables, stuff into avocado halves", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "American", "cooking_difficulty": "Easy", "prep_time": 10},

        {"recipe_id": 20, "name": "Vegetable and Tofu Stir-fry", "meal_type": "lunch", "protein": 15, "carbs": 25, "fat": 12, "calories": 280, "sodium": 450, "fiber": 8, "ingredients": "Tofu, broccoli, bell peppers, snap peas, soy sauce, brown rice", "instructions": "Stir-fry tofu and vegetables, serve over rice", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Asian", "cooking_difficulty": "Medium", "prep_time": 25},

        {"recipe_id": 21, "name": "Turkey and Vegetable Wrap", "meal_type": "lunch", "protein": 25, "carbs": 30, "fat": 10, "calories": 320, "sodium": 520, "fiber": 6, "ingredients": "Turkey breast, whole grain wrap, lettuce, tomato, bell pepper, hummus", "instructions": "Spread hummus on wrap, add turkey and vegetables, roll up", "vegetarian": False, "vegan": False, "gluten_free": False, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "American", "cooking_difficulty": "Easy", "prep_time": 10},

        {"recipe_id": 22, "name": "Salmon Poke Bowl", "meal_type": "lunch", "protein": 28, "carbs": 40, "fat": 14, "calories": 400, "sodium": 580, "fiber": 5, "ingredients": "Salmon, brown rice, avocado, cucumber, edamame, soy sauce", "instructions": "Arrange ingredients in bowl, drizzle with sauce", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Asian", "cooking_difficulty": "Medium", "prep_time": 20},

        {"recipe_id": 23, "name": "Quinoa and Black Bean Bowl", "meal_type": "lunch", "protein": 15, "carbs": 45, "fat": 8, "calories": 310, "sodium": 270, "fiber": 12, "ingredients": "Quinoa, black beans, corn, avocado, lime, cilantro", "instructions": "Combine ingredients, dress with lime juice", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mexican", "cooking_difficulty": "Easy", "prep_time": 15},

        {"recipe_id": 24, "name": "Egg and Vegetable Frittata", "meal_type": "lunch", "protein": 20, "carbs": 10, "fat": 15, "calories": 260, "sodium": 300, "fiber": 3, "ingredients": "Eggs, bell peppers, spinach, onions, feta cheese", "instructions": "Sauté vegetables, add beaten eggs, cook until set", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mediterranean", "cooking_difficulty": "Medium", "prep_time": 25},

        {"recipe_id": 25, "name": "Chicken and Vegetable Soup", "meal_type": "lunch", "protein": 22, "carbs": 20, "fat": 8, "calories": 240, "sodium": 480, "fiber": 5, "ingredients": "Chicken breast, carrots, celery, onion, chicken broth, herbs", "instructions": "Simmer all ingredients until vegetables and chicken are tender", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "American", "cooking_difficulty": "Easy", "prep_time": 45},

        {"recipe_id": 26, "name": "Spinach and Chickpea Curry", "meal_type": "lunch", "protein": 14, "carbs": 35, "fat": 10, "calories": 290, "sodium": 340, "fiber": 9, "ingredients": "Chickpeas, spinach, tomatoes, onion, garlic, curry spices, brown rice", "instructions": "Sauté onions and spices, add ingredients, simmer, serve over rice", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Indian", "cooking_difficulty": "Medium", "prep_time": 30},

        {"recipe_id": 27, "name": "Shrimp and Vegetable Skewers", "meal_type": "lunch", "protein": 25, "carbs": 15, "fat": 8, "calories": 240, "sodium": 520, "fiber": 4, "ingredients": "Shrimp, bell peppers, zucchini, onion, olive oil, herbs", "instructions": "Marinate shrimp, thread onto skewers with vegetables, grill", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Mediterranean", "cooking_difficulty": "Medium", "prep_time": 25},

        {"recipe_id": 28, "name": "Hearty Bean and Vegetable Soup", "meal_type": "lunch", "protein": 15, "carbs": 40, "fat": 5, "calories": 270, "sodium": 380, "fiber": 14, "ingredients": "Mixed beans, carrots, celery, kale, tomatoes, vegetable broth", "instructions": "Simmer all ingredients until vegetables are tender", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "American", "cooking_difficulty": "Easy", "prep_time": 40},

        {"recipe_id": 29, "name": "Mediterranean Tuna Salad", "meal_type": "lunch", "protein": 28, "carbs": 15, "fat": 12, "calories": 280, "sodium": 460, "fiber": 5, "ingredients": "Tuna, mixed greens, cherry tomatoes, olives, red onion, olive oil", "instructions": "Combine all ingredients, dress with olive oil and lemon juice", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Mediterranean", "cooking_difficulty": "Easy", "prep_time": 15},

        {"recipe_id": 30, "name": "Vegetable and Lentil Patties", "meal_type": "lunch", "protein": 12, "carbs": 30, "fat": 8, "calories": 240, "sodium": 290, "fiber": 10, "ingredients": "Lentils, carrots, zucchini, oats, egg, spices", "instructions": "Combine ingredients, form patties, bake until golden", "vegetarian": True, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mediterranean", "cooking_difficulty": "Medium", "prep_time": 35},

        # Dinner recipes
        {"recipe_id": 31, "name": "Baked Salmon with Roasted Vegetables", "meal_type": "dinner", "protein": 30, "carbs": 20, "fat": 15, "calories": 340, "sodium": 320, "fiber": 6, "ingredients": "Salmon fillet, broccoli, carrots, olive oil, lemon, herbs", "instructions": "Season salmon, arrange vegetables on baking sheet, bake", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 30},

        {"recipe_id": 32, "name": "Turkey Meatballs with Zucchini Noodles", "meal_type": "dinner", "protein": 28, "carbs": 15, "fat": 12, "calories": 280, "sodium": 420, "fiber": 5, "ingredients": "Ground turkey, egg, almond flour, zucchini, tomato sauce, herbs", "instructions": "Form meatballs, bake, serve with spiralized zucchini and sauce", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Italian", "cooking_difficulty": "Medium", "prep_time": 40},

        {"recipe_id": 33, "name": "Vegetable and Tofu Curry", "meal_type": "dinner", "protein": 15, "carbs": 30, "fat": 14, "calories": 310, "sodium": 380, "fiber": 8, "ingredients": "Tofu, broccoli, carrots, bell peppers, coconut milk, curry paste, brown rice", "instructions": "Sauté vegetables and tofu, add coconut milk and curry paste, serve over rice", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Asian", "cooking_difficulty": "Medium", "prep_time": 35},

        {"recipe_id": 34, "name": "Grilled Chicken with Quinoa and Vegetables", "meal_type": "dinner", "protein": 30, "carbs": 35, "fat": 10, "calories": 350, "sodium": 310, "fiber": 7, "ingredients": "Chicken breast, quinoa, bell peppers, zucchini, olive oil, herbs", "instructions": "Grill chicken, cook quinoa, sauté vegetables, combine", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 30},

        {"recipe_id": 35, "name": "Lentil and Vegetable Stew", "meal_type": "dinner", "protein": 18, "carbs": 40, "fat": 5, "calories": 280, "sodium": 340, "fiber": 12, "ingredients": "Lentils, onions, carrots, celery, tomatoes, vegetable broth, herbs", "instructions": "Sauté vegetables, add lentils and broth, simmer until tender", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mediterranean", "cooking_difficulty": "Easy", "prep_time": 45},

        {"recipe_id": 36, "name": "Baked Cod with Sweet Potato and Asparagus", "meal_type": "dinner", "protein": 25, "carbs": 30, "fat": 8, "calories": 290, "sodium": 320, "fiber": 6, "ingredients": "Cod fillet, sweet potato, asparagus, olive oil, lemon, herbs", "instructions": "Bake cod and vegetables seasoned with herbs", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 35},

        {"recipe_id": 37, "name": "Mushroom and Bell Pepper Fajitas", "meal_type": "dinner", "protein": 10, "carbs": 35, "fat": 12, "calories": 290, "sodium": 380, "fiber": 8, "ingredients": "Portobello mushrooms, bell peppers, onions, whole grain tortillas, spices", "instructions": "Sauté vegetables with spices, serve in tortillas", "vegetarian": True, "vegan": True, "gluten_free": False, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Mexican", "cooking_difficulty": "Easy", "prep_time": 20},

        {"recipe_id": 38, "name": "Shrimp and Vegetable Stir-fry", "meal_type": "dinner", "protein": 25, "carbs": 20, "fat": 8, "calories": 250, "sodium": 640, "fiber": 6, "ingredients": "Shrimp, broccoli, snap peas, carrots, garlic, ginger, soy sauce", "instructions": "Stir-fry shrimp and vegetables with aromatics and sauce", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Asian", "cooking_difficulty": "Medium", "prep_time": 25},

        {"recipe_id": 39, "name": "Eggplant and Chickpea Stew", "meal_type": "dinner", "protein": 12, "carbs": 35, "fat": 10, "calories": 280, "sodium": 310, "fiber": 10, "ingredients": "Eggplant, chickpeas, tomatoes, onions, garlic, herbs, spices", "instructions": "Sauté vegetables, add chickpeas and tomatoes, simmer", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mediterranean", "cooking_difficulty": "Medium", "prep_time": 35},

        {"recipe_id": 40, "name": "Baked Chicken with Mediterranean Vegetables", "meal_type": "dinner", "protein": 28, "carbs": 25, "fat": 12, "calories": 320, "sodium": 370, "fiber": 6, "ingredients": "Chicken thighs, zucchini, tomatoes, olives, feta cheese, herbs", "instructions": "Arrange chicken and vegetables in baking dish, season, bake", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Mediterranean", "cooking_difficulty": "Medium", "prep_time": 40},

        {"recipe_id": 41, "name": "Bean and Vegetable Enchiladas", "meal_type": "dinner", "protein": 15, "carbs": 45, "fat": 10, "calories": 330, "sodium": 520, "fiber": 11, "ingredients": "Black beans, corn, bell peppers, onion, whole grain tortillas, enchilada sauce", "instructions": "Fill tortillas with bean mixture, roll, top with sauce, bake", "vegetarian": True, "vegan": True, "gluten_free": False, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Mexican", "cooking_difficulty": "Medium", "prep_time": 45},

        {"recipe_id": 42, "name": "Sesame Salmon with Green Beans", "meal_type": "dinner", "protein": 30, "carbs": 15, "fat": 18, "calories": 340, "sodium": 390, "fiber": 4, "ingredients": "Salmon, green beans, sesame seeds, soy sauce, ginger, garlic", "instructions": "Pan-sear salmon with sesame seeds, serve with steamed green beans", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": False, "diet_type": "Asian", "cooking_difficulty": "Medium", "prep_time": 25},

        {"recipe_id": 43, "name": "Turkey and Vegetable Stuffed Peppers", "meal_type": "dinner", "protein": 25, "carbs": 25, "fat": 10, "calories": 290, "sodium": 360, "fiber": 7, "ingredients": "Ground turkey, bell peppers, onions, quinoa, tomato sauce, spices", "instructions": "Cook turkey and quinoa, stuff into peppers, bake", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "American", "cooking_difficulty": "Medium", "prep_time": 45},

        {"recipe_id": 44, "name": "Beef and Broccoli Stir-fry", "meal_type": "dinner", "protein": 28, "carbs": 20, "fat": 15, "calories": 330, "sodium": 680, "fiber": 5, "ingredients": "Lean beef strips, broccoli, garlic, ginger, soy sauce, brown rice", "instructions": "Stir-fry beef and broccoli with aromatics, serve over rice", "vegetarian": False, "vegan": False, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": False, "low_sodium": False, "diet_type": "Asian", "cooking_difficulty": "Medium", "prep_time": 30},

        {"recipe_id": 45, "name": "Vegetable and Bean Paella", "meal_type": "dinner", "protein": 14, "carbs": 40, "fat": 8, "calories": 290, "sodium": 340, "fiber": 10, "ingredients": "Brown rice, mixed beans, bell peppers, peas, tomatoes, saffron, paprika", "instructions": "Sauté vegetables, add rice and broth, simmer until rice is cooked", "vegetarian": True, "vegan": True, "gluten_free": True, "diabetes_friendly": True, "heart_healthy": True, "low_sodium": True, "diet_type": "Mediterranean", "cooking_difficulty": "Hard", "prep_time": 50}
    ]

    # Convert the list of recipes to a DataFrame
    df = pd.DataFrame(recipes)

    # Save the DataFrame to a CSV file
    df.to_csv("recipes_dataset.csv", index=False)

    print("Comprehensive dataset created and saved as 'recipes_dataset.csv'")
    print(f"Total recipes: {len(df)}")
    print(f"Breakfast recipes: {len(df[df.meal_type == 'breakfast'])}")
    print(f"Lunch recipes: {len(df[df.meal_type == 'lunch'])}")
    print(f"Dinner recipes: {len(df[df.meal_type == 'dinner'])}")

    return df

# Call the function to create the dataset
if __name__ == "__main__":
    recipe_df = create_comprehensive_recipe_dataset()
# Out:
# Comprehensive dataset created and saved as 'recipes_dataset.csv'
# Total recipes: 45
# Breakfast recipes: 15
# Lunch recipes: 15
# Dinner recipes: 15
